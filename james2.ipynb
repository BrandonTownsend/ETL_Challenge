# %%
import os 
import pandas as pd 
import matplotlib.pyplot as plt
import numpy as np
import requests
import xml.etree.ElementTree as etree

from mpl_toolkits.mplot3d import Axes3D
from sklearn.preprocessing import StandardScaler
from xml.dom import minidom
from lxml import html, etree

# %%
anime_page = requests.get("https://www.animenewsnetwork.com/encyclopedia/reports.xml?id=172")
#print(anime_page.content)

# %%
tree = etree.parse("Anime report1.xml")
root = tree.getroot()
columns = ["anime", "nb_votes", "nb_seen", "straight_average", "weighted_average", "bayesian_average"]
anime_df = pd.DataFrame(columns = columns)

for node in root: 
    anime = node.find("anime").text if node is not None else None
    votes = node.find("nb_votes").text if node is not None else None
    viewed = node.find("nb_seen").text if node is not None else None
    average = node.find("straight_average").text if node is not None else None
    weighted = node.find("weighted_average").text if node is not None else None
    bayesian = node.find("bayesian_average").text if node is not None else None
    anime_df = anime_df.append(pd.Series([anime, votes, viewed, average, weighted, bayesian], index = columns), ignore_index = True)

# %%
anime_df
# Out:
#                                               anime nb_votes nb_seen  \
# 0                  Fullmetal Alchemist: Brotherhood     5815   10858
# 1                                        your name.     1100    1481
# 2                                       Steins;Gate     4655    6811
# 3                               Clannad After Story     5180    8361
# 4             Rurouni Kenshin: Trust Betrayal (OAV)     6649   10385
# 5           Code Geass: Lelouch of the Rebellion R2     7868   12551
# 6                                     Spirited Away    10546   15397
# 7                        Mushishi: The Next Chapter      512     848
# 8                                      Cowboy Bebop    12243   21026
# 9                                 Princess Mononoke     9835   15401
# 10                                     Silent Voice      559     764
# 11                 Disappearance of Haruhi Suzumiya     2792    4029
# 12              Legend of the Galactic Heroes (OAV)      726    1141
# 13                                        Mushi-Shi     4995    8163
# 14                                       Death Note    12911   22216
# 15                                    Made in Abyss      644     883
# 16           Maria Watches Over Us 3rd Season (OAV)      726    1044
# 17        Maria Watches Over Us Season 2: Printemps     1343    1820
# 18             Code Geass: Lelouch of the Rebellion     9181   15212
# 19  Descending Stories: Showa Genroku Rakugo Shinju      182     260
# 20                                       Bunny Drop     1801    2667
# 21              anohana: The Flower We Saw That Day     3235    4878
# 22                 Maria Watches Over Us 4th Season      511     722
# 23                              Gintama (TV 4/2015)      151     291
# 24                                          Monster     3472    5781
# 25            Evangelion: 2.0 You Can (Not) Advance     2090    3359
# 26                             Gintama' (TV 2/2011)      432     888
# 27                             Gintama' (TV 3/2012)      262     482
# 28  Ghost in the Shell: Stand Alone Complex 2nd GIG     2597    4892
# 29                           Grave of the Fireflies     4593    6925
# 30                                       Cross Game      688    1060
# 31                                  Fighting Spirit     1628    2824
# 32                              Fullmetal Alchemist    13436   23626
# 33                                      Summer Wars     3400    4573
# 34               Nausicaä of the Valley of the Wind     5066    7898
# 35                                 Nodame Cantabile     2772    4331
# 36                      Girl Who Leapt Through Time     5537    7766
# 37                         5 Centimeters Per Second     5777    8203
# 38                                    Gurren Lagann     6975   11421
# 39                        Hunter × Hunter (TV 2011)     1043    1997
# 40                 Garden of Sinners (movie series)     1702    2700
# 41                                    Wolf Children     1159    1631
# 42                               My Neighbor Totoro     4686    7403
# 43                                         Baccano!     4198    6990
# 44                         Gintama: The Final Movie      166     257
# 45                              Honey and Clover II     2053    3089
# 46                      Attack on Titan (TV 4/2019)      279     624
# 47                 Natsume's Book of Friends (TV 4)      579    1005
# 48                   Hajime no Ippo: New Challenger      715    1206
# 49                                Kanon (TV 2/2006)     3643    5693
#
#      straight_average   weighted_average   bayesian_average
# 0   9.106100082397461  9.095100402832031  9.091821670532227
# 1   9.104499816894531  9.087200164794922   9.07010269165039
# 2   9.138099670410156  9.059100151062012  9.055098533630371
# 3   8.951000213623047  9.055299758911133  9.051711082458496
# 4   8.923399925231934  8.972299575805664   8.96965217590332
# 5   9.020099639892578  8.932000160217285  8.929823875427246
# 6   8.969799995422363  8.926199913024902  8.924582481384277
# 7   8.824199676513672  8.933699607849121  8.900931358337402
# 8   8.933099746704102  8.895099639892578  8.893735885620117
# 9   8.928099632263184  8.864999771118164    8.8633394241333
# 10  8.856900215148926  8.888799667358398  8.859671592712402
# 11  8.868599891662598  8.861599922180176   8.85578441619873
# 12  8.785099983215332  8.834799766540527  8.813140869140625
# 13  8.803199768066406   8.79259967803955  8.789508819580078
# 14  8.863300323486328  8.781499862670898  8.780312538146973
# 15  8.807499885559082   8.79539966583252  8.771754264831543
# 16    8.7947998046875  8.790200233459473  8.769267082214355
# 17  8.829500198364258  8.760100364685059    8.7489652633667
# 18  8.854399681091309   8.74120044708252  8.739583969116211
# 19  8.818699836730957  8.812000274658203  8.731019020080566
# 20  8.789600372314453  8.729399681091309  8.721281051635742
# 21  8.786100387573242  8.725099563598633  8.720582008361816
# 22  8.747599601745605  8.748600006103516  8.720015525817871
# 23  8.768199920654297  8.811699867248535  8.715338706970215
# 24   8.76669979095459  8.715999603271484  8.711820602416992
# 25  8.775099754333496     8.714599609375  8.707681655883789
# 26  8.740699768066406  8.739999771118164  8.706562042236328
# 27  8.561100006103516  8.741499900817871  8.687250137329102
# 28  8.749300003051758  8.675299644470215  8.669906616210938
# 29  8.707799911499023  8.671600341796875  8.668554306030273
# 30  8.780500411987305  8.676400184631348  8.656281471252441
# 31  8.746299743652344  8.664299964904785  8.655800819396973
# 32  8.728899955749512  8.649900436401367  8.648877143859863
# 33  8.743800163269043  8.652299880981445    8.6482572555542
# 34  8.678999900817871  8.639800071716309  8.637113571166992
# 35  8.666299819946289  8.641599655151367  8.636691093444824
# 36  8.671099662780762  8.637100219726562  8.634647369384766
# 37  8.693099975585938  8.624199867248535  8.621875762939453
# 38  8.735300064086914   8.61970043182373  8.617782592773438
# 39   8.69890022277832  8.622900009155273  8.610159873962402
# 40    8.7121000289917  8.616600036621094   8.60880184173584
# 41   8.65310001373291  8.613100051879883   8.60172176361084
# 42  8.653200149536133  8.599699974060059  8.596898078918457
# 43  8.673399925231934   8.59119987487793   8.58809757232666
# 44  8.710800170898438  8.653900146484375  8.576297760009766
# 45  8.569899559020996  8.581700325012207  8.575430870056152
# 46  8.677399635314941  8.618800163269043  8.572779655456543
# 47  8.644200325012207  8.590100288391113  8.568022727966309
# 48  8.630800247192383  8.576899528503418   8.55916976928711
# 49  8.641799926757812  8.559900283813477  8.556429862976074

# %%
#csv_anime= "resources/anime.csv"
#data_df = pd.read_csv(csv_anime)
#data_df

csv2_anime= "resources/animelist.csv"
csv2data_df = pd.read_csv(csv2_anime)
csv2data_df
# Out:
#        anime_id                                  title  \
# 0         36089                                      9
# 1         34595                      "Parade" de Satie
# 2          3269                    .hack//G.U. Trilogy
# 3          4469       .hack//G.U. Trilogy: Parody Mode
# 4           454                            .hack//Gift
# ...         ...                                    ...
# 14473     26089             Gutchonpa Omoshiro Hanashi
# 14474     21525                   Geba Geba Shou Time!
# 14475     37897            Godzilla: Hoshi wo Kuu Mono
# 14476     34193  Nippon Mukashibanashi: Sannen Netarou
# 14477     37908             Senjou no Valkyria Special
#
#                                   anime                  anime_japanese  \
# 0                                     9                               9
# 1                     "Parade" de Satie                      サティの「パラード」
# 2                   .hack//G.U. Trilogy             .hack//G.U. Trilogy
# 3      .hack//G.U. Trilogy: Parody Mode             .hack//G.U. Trilogy
# 4                           .hack//Gift                     .hack//GIFT
# ...                                 ...                             ...
# 14473                               NaN                     グッチョンパおもしろ話
# 14474                               NaN                       ゲバゲバ笑タイム!
# 14475                               NaN                GODZILLA -星を喰う者-
# 14476                               NaN                   日本昔ばなし 三ねん寝太郎
# 14477                               NaN  戦場のヴァルキュリア Valkyria Chronicles
#
#                                   title_synonyms  \
# 0                               group_inou, Nine
# 1                          Satie&#039;s "Parade"
# 2                                            NaN
# 3                                            NaN
# 4                                            NaN
# ...                                          ...
# 14473                                        NaN
# 14474                                        NaN
# 14475  Godzilla Part 3, Godzilla: Eater of Stars
# 14476                                        NaN
# 14477        Senjou no Valkyria Fake Movie Promo
#
#                                                image_url     type    source  \
# 0      https://myanimelist.cdn-dena.com/images/anime/...    Music  Original
# 1      https://myanimelist.cdn-dena.com/images/anime/...    Movie  Original
# 2      https://myanimelist.cdn-dena.com/images/anime/...    Movie      Game
# 3      https://myanimelist.cdn-dena.com/images/anime/...  Special      Game
# 4      https://myanimelist.cdn-dena.com/images/anime/...      OVA  Original
# ...                                                  ...      ...       ...
# 14473  https://myanimelist.cdn-dena.com/images/anime/...       TV   Unknown
# 14474  https://myanimelist.cdn-dena.com/images/anime/...      OVA   Unknown
# 14475  https://myanimelist.cdn-dena.com/images/anime/...    Movie     Other
# 14476  https://myanimelist.cdn-dena.com/images/anime/...      OVA     Other
# 14477  https://myanimelist.cdn-dena.com/images/anime/...  Special   Unknown
#
#        episodes           status  ...  \
# 0             1  Finished Airing  ...
# 1             1  Finished Airing  ...
# 2             1  Finished Airing  ...
# 3             1  Finished Airing  ...
# 4             1  Finished Airing  ...
# ...         ...              ...  ...
# 14473         5  Finished Airing  ...
# 14474         1  Finished Airing  ...
# 14475         1    Not yet aired  ...
# 14476         1  Finished Airing  ...
# 14477         1  Finished Airing  ...
#
#                                               background  premiered broadcast  \
# 0                                                    NaN        NaN       NaN
# 1      French composer Erik Satie (1866-1925) created...        NaN       NaN
# 2                                                    NaN        NaN       NaN
# 3                                                    NaN        NaN       NaN
# 4                                                    NaN        NaN       NaN
# ...                                                  ...        ...       ...
# 14473                                                NaN  Fall 1987   Unknown
# 14474                                                NaN        NaN       NaN
# 14475                                                NaN        NaN       NaN
# 14476                                                NaN        NaN       NaN
# 14477                                                NaN        NaN       NaN
#
#                                                  related  \
# 0                                                     []
# 1                                                     []
# 2      {'Prequel': [{'mal_id': 873, 'type': 'anime', ...
# 3      {'Parent story': [{'mal_id': 3269, 'type': 'an...
# 4      {'Parent story': [{'mal_id': 48, 'type': 'anim...
# ...                                                  ...
# 14473  {'Other': [{'mal_id': 26087, 'type': 'anime', ...
# 14474                                                 []
# 14475  {'Prequel': [{'mal_id': 36816, 'type': 'anime'...
# 14476                                                 []
# 14477  {'Other': [{'mal_id': 5507, 'type': 'anime', '...
#
#                            producer                          licensor  \
# 0                               NaN                               NaN
# 1                               NaN                               NaN
# 2      Bandai Visual, CyberConnect2  Funimation, Bandai Entertainment
# 3                     Bandai Visual                               NaN
# 4                     CyberConnect2              Bandai Entertainment
# ...                             ...                               ...
# 14473                           NaN                               NaN
# 14474                  Studio Lotus                               NaN
# 14475                           NaN                               NaN
# 14476                           NaN                               NaN
# 14477                           NaN                               NaN
#
#                          studio                                  genre  \
# 0                           NaN                                  Music
# 1      Yamamura Animation, Inc.                        Music, Dementia
# 2                           NaN          Action, Fantasy, Game, Sci-Fi
# 3                           NaN  Fantasy, Game, Comedy, Sci-Fi, Parody
# 4                     Bee Train                  Comedy, Fantasy, Game
# ...                         ...                                    ...
# 14473                       NaN                                   Kids
# 14474                       NaN                                 Comedy
# 14475                       NaN     Action, Sci-Fi, Adventure, Fantasy
# 14476                       NaN                          Fantasy, Kids
# 14477              A-1 Pictures                                 Comedy
#
#                     opening_theme                     ending_theme
# 0                              []                               []
# 1                              []                               []
# 2                              []   ['"Deepest Memories" by Lien']
# 3                              []                               []
# 4      ['"Obsession" by See-Saw']  ['"Yasashii Yoake" by See-Saw']
# ...                           ...                              ...
# 14473                          []                               []
# 14474                          []                               []
# 14475                          []                               []
# 14476                          []                               []
# 14477                          []                               []
#
# [14478 rows x 31 columns]

# %%
csv2data_df.dtypes
# Out:
# anime_id            int64
# title              object
# anime              object
# anime_japanese     object
# title_synonyms     object
# image_url          object
# type               object
# source             object
# episodes            int64
# status             object
# airing               bool
# aired_string       object
# aired              object
# duration           object
# rating             object
# score             float64
# scored_by           int64
# rank              float64
# popularity          int64
# members             int64
# favorites           int64
# background         object
# premiered          object
# broadcast          object
# related            object
# producer           object
# licensor           object
# studio             object
# genre              object
# opening_theme      object
# ending_theme       object
# dtype: object

# %%
csvtv_df = csv2data_df[csv2data_df.type == 'TV']
csvtv_df
# Out:
#        anime_id                                         title  \
# 5           298             .hack//Tasogare no Udewa Densetsu
# 9           873                                  .hack//Roots
# 10           48                                   .hack//Sign
# 11         1684                               Dotto Koni-chan
# 13        10163  C: The Money of Soul and Possibility Control
# ...         ...                                           ...
# 14410     37778                                   Pastel Life
# 14424     37662                        Shinya! Tensai Bakabon
# 14448     37428                   Chara to Otamajakushi Shima
# 14465     37787                                     Space Bug
# 14473     26089                    Gutchonpa Omoshiro Hanashi
#
#                                                  anime  \
# 5                        .hack//Legend Of The Twilight
# 9                                         .hack//roots
# 10                                         .hack//Sign
# 11                                          .Koni-chan
# 13     [C] CONTROL - The Money and Soul of Possibility
# ...                                                ...
# 14410                                              NaN
# 14424                                              NaN
# 14448                                              NaN
# 14465                                              NaN
# 14473                                              NaN
#
#                                       anime_japanese  \
# 5                                     .hack//黄昏の腕輪伝説
# 9                                       .hack//Roots
# 10                                       .hack//SIGN
# 11                                        ドッとKONIちゃん
# 13     「C」 THE MONEY OF SOUL AND POSSIBILITY CONTROL
# ...                                              ...
# 14410                                        ぱすてるらいふ
# 14424                                     深夜! 天才バカボン
# 14448                                   キャラとおたまじゃくし島
# 14465                                         スペースバグ
# 14473                                    グッチョンパおもしろ話
#
#                                           title_synonyms  \
# 5      .hack//Udeden, .hack//Legend of the Twilight B...
# 9                                                    NaN
# 10                                                   NaN
# 11                                                   NaN
# 13         [C] The Money of Soul and Possibility Control
# ...                                                  ...
# 14410                                                NaN
# 14424                         Late Night! Genius Bakabon
# 14448                                                NaN
# 14465                                                NaN
# 14473                                                NaN
#
#                                                image_url type    source  \
# 5      https://myanimelist.cdn-dena.com/images/anime/...   TV     Manga
# 9      https://myanimelist.cdn-dena.com/images/anime/...   TV  Original
# 10     https://myanimelist.cdn-dena.com/images/anime/...   TV  Original
# 11     https://myanimelist.cdn-dena.com/images/anime/...   TV  Original
# 13     https://myanimelist.cdn-dena.com/images/anime/...   TV  Original
# ...                                                  ...  ...       ...
# 14410  https://myanimelist.cdn-dena.com/images/anime/...   TV   Unknown
# 14424  https://myanimelist.cdn-dena.com/images/anime/...   TV     Manga
# 14448  https://myanimelist.cdn-dena.com/images/anime/...   TV  Original
# 14465  https://myanimelist.cdn-dena.com/images/anime/...   TV  Original
# 14473  https://myanimelist.cdn-dena.com/images/anime/...   TV   Unknown
#
#        episodes            status  ...  background    premiered  \
# 5            12   Finished Airing  ...         NaN  Winter 2003
# 9            26   Finished Airing  ...         NaN  Spring 2006
# 10           26   Finished Airing  ...         NaN  Spring 2002
# 11           26   Finished Airing  ...         NaN    Fall 2000
# 13           11   Finished Airing  ...         NaN  Spring 2011
# ...         ...               ...  ...         ...          ...
# 14410         6  Currently Airing  ...         NaN  Spring 2018
# 14424         0     Not yet aired  ...         NaN  Summer 2018
# 14448         0  Currently Airing  ...         NaN  Spring 2018
# 14465         0     Not yet aired  ...         NaN  Summer 2018
# 14473         5   Finished Airing  ...         NaN    Fall 1987
#
#                     broadcast  \
# 5                     Unknown
# 9                     Unknown
# 10       Thursdays at Unknown
# 11     Sundays at 17:00 (JST)
# 13     Fridays at 00:45 (JST)
# ...                       ...
# 14410                 Unknown
# 14424                 Unknown
# 14448  Mondays at 10:15 (JST)
# 14465  Sundays at 10:30 (JST)
# 14473                 Unknown
#
#                                                  related  \
# 5      {'Adaptation': [{'mal_id': 117, 'type': 'manga...
# 9      {'Prequel': [{'mal_id': 48, 'type': 'anime', '...
# 10     {'Sequel': [{'mal_id': 298, 'type': 'anime', '...
# 11                                                    []
# 13                                                    []
# ...                                                  ...
# 14410  {'Spin-off': [{'mal_id': 33573, 'type': 'anime...
# 14424  {'Other': [{'mal_id': 11268, 'type': 'anime', ...
# 14448                                                 []
# 14465                                                 []
# 14473  {'Other': [{'mal_id': 26087, 'type': 'anime', ...
#
#                                                 producer  \
# 5                      Bandai Visual, Yomiko Advertising
# 9                 TV Tokyo, Bandai Visual, CyberConnect2
# 10     Bandai Visual, Yomiko Advertising, Bandai, Cyb...
# 11                                         Genco, Animax
# 13     Fuji TV, Jumondo, Sony Music Entertainment, Fu...
# ...                                                  ...
# 14410                                                NaN
# 14424                                                NaN
# 14448                                        Dentsu, NHK
# 14465                                                NaN
# 14473                                                NaN
#
#                                licensor                studio  \
# 5      Funimation, Bandai Entertainment             Bee Train
# 9      Funimation, Bandai Entertainment             Bee Train
# 10     Funimation, Bandai Entertainment             Bee Train
# 11                                  NaN                 Shaft
# 13                           Funimation  Tatsunoko Production
# ...                                 ...                   ...
# 14410                               NaN                   NaN
# 14424                               NaN                   NaN
# 14448                               NaN         33 Collective
# 14465                               NaN                   NaN
# 14473                               NaN                   NaN
#
#                                                    genre  \
# 5      Adventure, Comedy, Fantasy, Game, Sci-Fi, Shounen
# 9                Adventure, Drama, Fantasy, Game, Sci-Fi
# 10      Game, Sci-Fi, Adventure, Mystery, Magic, Fantasy
# 11                                                Comedy
# 13                Action, Mystery, Super Power, Thriller
# ...                                                  ...
# 14410                               Music, Slice of Life
# 14424                              Slice of Life, Comedy
# 14448                           Adventure, Fantasy, Kids
# 14465                                   Adventure, Space
# 14473                                               Kids
#
#                                            opening_theme  \
# 5          ['"New World" by ROUND TABLE featuring Nino']
# 9           ['"Silly-go-Round" by FictionJuction YUUKA']
# 10                            ['"Obsession" by See-Saw']
# 11                          ['"Kyaradamon" by ShinoRyu']
# 13     ['"Matryoshka (マトリョーシカ)" by NICO Touches the W...
# ...                                                  ...
# 14410  ['"Shuwarin☆Dreaming (しゅわりん☆どり〜みん)" by Pastel＊...
# 14424  ['"BAKA-BONSOIR!" by B.P.O -Bakabon-no Papa Or...
# 14448                                                 []
# 14465                                                 []
# 14473                                                 []
#
#                                             ending_theme
# 5                         ['"Emerald Green" by See-Saw']
# 9      ['#1: "Boukoku Kakusei - Catharsis" by Ali Pro...
# 10              ['"Yasashii Yoake (優しい夜明け)" by See-Saw']
# 11                ['"Sailing Dream" by Shinohara Tomoe']
# 13                   ['"RPG" by school food punishment']
# ...                                                  ...
# 14410                                                 []
# 14424                                                 []
# 14448                                                 []
# 14465                                                 []
# 14473                                                 []
#
# [4271 rows x 31 columns]

# %%
tvlist_df = anime_df.merge(csvtv_df, how='outer')
tvlist_df["weighted_average"] = tvlist_df.weighted_average.astype(float)
tvlist2_df = tvlist_df[tvlist_df.weighted_average > 8.75]
tvlist2_df.to_csv(r'resources\TopTV.csv', index = False)
#tvlist2_df

# %%
list_df.dtypes

# %%
join_df = pd.merge(csv2data_df, anime_df, on='anime', how='outer')
final_df = join_df[join_df['nb_votes'].notna()]
final_df.drop(final_df.columns[0], axis=1, inplace=True)
final_df.style.hide_index()
print('Number of colums in Dataframe : ', len(final_df.columns))
print('Number of rows in Dataframe : ', len(final_df.index))

# %%
final_df

# %%
list_df["nb_votes"] = list_df.nb_votes.astype(float)

# %%
list_df["nb_seen"] = list_df.nb_seen.astype(float)

# %%
list_df["straight_average"] = list_df.straight_average.astype(float)

# %%
list_df["weighted_average"] = list_df.weighted_average.astype(float)

# %%
list_df["bayesian_average"] = list_df.bayesian_average.astype(float)

# %%
list_df.dtypes

# %%
list_df.sort_values(by=['straight_average'], inplace=True, ascending=False)
list_df

# %%
list3_df = list_df[list_df.nb_seen > 1200]
list3_df

# %%
list2_df = list_df.drop(list_df[(list_df.nb_votes < 1000)].index)
list2_df

# %%
list_df2= list_df[['anime', 'manga', 'nb_votes', 'nb_seen', 'straight_average', 'weighted_average', 'bayesian_average']]
list_df2

# %%
list_df2.sort_values(by=['nb_seen', 'straight_average'], inplace=True, ascending=False)
list_df2
